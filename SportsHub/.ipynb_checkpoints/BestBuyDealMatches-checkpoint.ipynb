# %% [markdown]
# ### Twitter API

# %%
from TwitterAPI import TwitterAPI, TwitterOAuth, TwitterPager

# %%
o = TwitterOAuth.read_file(r'C:\apache-tomcat-7.0.34\webapps\EWA_Project\credentials.txt')

# %%
o.access_token_key
# Out:
# '534492178-0id9VSkSJGUtl5JRBjt3lwtKAXPl6EtND2grBvkR'

# %%
# Using OAuth1...
twitter = TwitterAPI(o.consumer_key,
                 o.consumer_secret,
                 o.access_token_key,
                 o.access_token_secret)

# %%
help(twitter)
# Out:
# Help on TwitterAPI in module TwitterAPI.TwitterAPI object:
#
# class TwitterAPI(builtins.object)
#  |  TwitterAPI(consumer_key=None, consumer_secret=None, access_token_key=None, access_token_secret=None, auth_type='oAuth1', proxy_url=None)
#  |
#  |  Access REST API or Streaming API resources.
#  |
#  |  :param consumer_key: Twitter application consumer key
#  |  :param consumer_secret: Twitter application consumer secret
#  |  :param access_token_key: Twitter application access token key
#  |  :param access_token_secret: Twitter application access token secret
#  |  :param auth_type: "oAuth1" (default) or "oAuth2"
#  |  :param proxy_url: HTTPS proxy URL string (ex. "https://USER:PASSWORD@SERVER:PORT"),
#  |                    or dict of URLs (ex. {'http':'http://SERVER', 'https':'https://SERVER'})
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, consumer_key=None, consumer_secret=None, access_token_key=None, access_token_secret=None, auth_type='oAuth1', proxy_url=None)
#  |      Initialize with your Twitter application credentials
#  |
#  |  request(self, resource, params=None, files=None, method_override=None)
#  |      Request a Twitter REST API or Streaming API resource.
#  |
#  |      :param resource: A valid Twitter endpoint (ex. "search/tweets")
#  |      :param params: Dictionary with endpoint parameters or None (default)
#  |      :param files: Dictionary with multipart-encoded file or None (default)
#  |      :param method_override: Request method to override or None (default)
#  |
#  |      :returns: TwitterResponse
#  |      :raises: TwitterConnectionError
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  CONNECTION_TIMEOUT = 5
#  |
#  |  REST_TIMEOUT = 5
#  |
#  |  STREAMING_TIMEOUT = 90
#  |
#  |  USER_AGENT = 'python-TwitterAPI'

# %%
# What can we do with this twitter object?
# builtin method `dir` tells us...
dir(twitter)
# Out:
# ['CONNECTION_TIMEOUT',
#  'REST_TIMEOUT',
#  'STREAMING_TIMEOUT',
#  'USER_AGENT',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_get_endpoint',
#  '_prepare_url',
#  'auth',
#  'proxies',
#  'request']

# %%
twitter.auth

# %%
# Get help on the `request` method using the builtin method called...`help`
help(twitter.request)
# Out:
# Help on method request in module TwitterAPI.TwitterAPI:
#
# request(resource, params=None, files=None, method_override=None) method of TwitterAPI.TwitterAPI.TwitterAPI instance
#     Request a Twitter REST API or Streaming API resource.
#
#     :param resource: A valid Twitter endpoint (ex. "search/tweets")
#     :param params: Dictionary with endpoint parameters or None (default)
#     :param files: Dictionary with multipart-encoded file or None (default)
#     :param method_override: Request method to override or None (default)
#
#     :returns: TwitterResponse
#     :raises: TwitterConnectionError

# %%
# Let's start by querying the search API
response = twitter.request('search/tweets', {'q': 'big+data'})

# %%
# What object is returned?
# builtin type method will tell us.
print(type(response))
dir(response)
# Out:
# <class 'TwitterAPI.TwitterAPI.TwitterResponse'>
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'close',
#  'get_iterator',
#  'get_quota',
#  'headers',
#  'json',
#  'response',
#  'status_code',
#  'stream',
#  'text']

# %%
response.json
# Out:
# <bound method TwitterResponse.json of <TwitterAPI.TwitterAPI.TwitterResponse object at 0x0000020F5E4639B0>>

# %%
response.status_code
# See https://dev.twitter.com/overview/api/response-codes
# Out:
# 200

# %%
tweets = [r for r in response]

# %%
print('found %d tweets' % len(tweets))
# Out:
# found 15 tweets

# %%
type(tweets)
# Out:
# list

# %%
type(tweets[0])
# Out:
# dict

# %%
tweets[0]
# Out:
# {'created_at': 'Sun Nov 24 20:16:08 +0000 2019',
#  'id': 1198696824573349888,
#  'id_str': '1198696824573349888',
#  'text': 'RT @antgrasso: The Chief Data Officer role was created in response to Big Data As companies accumulated ever-growing stores of data, someon…',
#  'truncated': False,
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'antgrasso',
#     'name': 'Antonio Grasso',
#     'id': 4338452835,
#     'id_str': '4338452835',
#     'indices': [3, 13]}],
#   'urls': []},
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 945184607728734209,
#   'id_str': '945184607728734209',
#   'name': 'Startup Or Scaleup',
#   'screen_name': 'StartupNScaleup',
#   'location': 'Global',
#   'description': 'Social digital+technology daily. This channel share insights and learning materials about technology and strategy for #Startup and/or #Scaleup.',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 467,
#   'friends_count': 471,
#   'listed_count': 3,
#   'created_at': 'Mon Dec 25 06:49:05 +0000 2017',
#   'favourites_count': 1848,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 1635,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1161279306011688962/EzVWLANP_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1161279306011688962/EzVWLANP_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/945184607728734209/1565705713',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'retweeted_status': {'created_at': 'Sun Nov 24 15:00:30 +0000 2019',
#   'id': 1198617393687334919,
#   'id_str': '1198617393687334919',
#   'text': 'The Chief Data Officer role was created in response to Big Data As companies accumulated ever-growing stores of dat… https://t.co/r299NynDRZ',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/r299NynDRZ',
#      'expanded_url': 'https://twitter.com/i/web/status/1198617393687334919',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 4338452835,
#    'id_str': '4338452835',
#    'name': 'Antonio Grasso',
#    'screen_name': 'antgrasso',
#    'location': 'Italy - Europe',
#    'description': 'Digital Transformation Advisor | B2B Tech Influencer | Author & Speaker | #Startups Mentor | CEO @dbi_srl | #AI #Blockchain #CyberSecurity #Energy #FinServ #IoT',
#    'url': 'https://t.co/uYvrqTqFA8',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/uYvrqTqFA8',
#        'expanded_url': 'https://www.dbi.srl',
#        'display_url': 'dbi.srl',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 87225,
#    'friends_count': 32691,
#    'listed_count': 1674,
#    'created_at': 'Tue Dec 01 09:49:04 +0000 2015',
#    'favourites_count': 105130,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 35698,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '0099B9',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1121360169319981058/1W13Y7Vi_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1121360169319981058/1W13Y7Vi_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4338452835/1556958142',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 52,
#   'favorite_count': 70,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  'is_quote_status': False,
#  'retweet_count': 52,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'lang': 'en'}

# %%
help(tweets[0])
# Out:
# Help on dict object:
#
# class dict(object)
#  |  dict() -> new empty dictionary
#  |  dict(mapping) -> new dictionary initialized from a mapping object's
#  |      (key, value) pairs
#  |  dict(iterable) -> new dictionary initialized as if via:
#  |      d = {}
#  |      for k, v in iterable:
#  |          d[k] = v
#  |  dict(**kwargs) -> new dictionary initialized with the name=value pairs
#  |      in the keyword argument list.  For example:  dict(one=1, two=2)
#  |
#  |  Methods defined here:
#  |
#  |  __contains__(self, key, /)
#  |      True if the dictionary has the specified key, else False.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __len__(self, /)
#  |      Return len(self).
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __setitem__(self, key, value, /)
#  |      Set self[key] to value.
#  |
#  |  __sizeof__(...)
#  |      D.__sizeof__() -> size of D in memory, in bytes
#  |
#  |  clear(...)
#  |      D.clear() -> None.  Remove all items from D.
#  |
#  |  copy(...)
#  |      D.copy() -> a shallow copy of D
#  |
#  |  get(self, key, default=None, /)
#  |      Return the value for key if key is in the dictionary, else default.
#  |
#  |  items(...)
#  |      D.items() -> a set-like object providing a view on D's items
#  |
#  |  keys(...)
#  |      D.keys() -> a set-like object providing a view on D's keys
#  |
#  |  pop(...)
#  |      D.pop(k[,d]) -> v, remove specified key and return the corresponding value.
#  |      If key is not found, d is returned if given, otherwise KeyError is raised
#  |
#  |  popitem(...)
#  |      D.popitem() -> (k, v), remove and return some (key, value) pair as a
#  |      2-tuple; but raise KeyError if D is empty.
#  |
#  |  setdefault(self, key, default=None, /)
#  |      Insert key with a value of default if key is not in the dictionary.
#  |
#  |      Return the value for key if key is in the dictionary, else default.
#  |
#  |  update(...)
#  |      D.update([E, ]**F) -> None.  Update D from dict/iterable E and F.
#  |      If E is present and has a .keys() method, then does:  for k in E: D[k] = E[k]
#  |      If E is present and lacks a .keys() method, then does:  for k, v in E: D[k] = v
#  |      In either case, this is followed by: for k in F:  D[k] = F[k]
#  |
#  |  values(...)
#  |      D.values() -> an object providing a view on D's values
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  fromkeys(iterable, value=None, /) from builtins.type
#  |      Create a new dictionary with keys from iterable and values set to value.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __hash__ = None

# %%
tweets[0].keys()
# Out:
# dict_keys(['created_at', 'id', 'id_str', 'text', 'truncated', 'entities', 'metadata', 'source', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'retweeted_status', 'is_quote_status', 'retweet_count', 'favorite_count', 'favorited', 'retweeted', 'lang'])

# %%
tweets[0]['text']
# Out:
# 'RT @antgrasso: The Chief Data Officer role was created in response to Big Data As companies accumulated ever-growing stores of data, someon…'

# %%
tweets[0]['created_at']
# Out:
# 'Sun Nov 24 20:16:08 +0000 2019'

# %%
tweets[0]['text']
# Out:
# 'RT @antgrasso: The Chief Data Officer role was created in response to Big Data As companies accumulated ever-growing stores of data, someon…'

# %%
tweets[0]['user']
# Out:
# {'id': 945184607728734209,
#  'id_str': '945184607728734209',
#  'name': 'Startup Or Scaleup',
#  'screen_name': 'StartupNScaleup',
#  'location': 'Global',
#  'description': 'Social digital+technology daily. This channel share insights and learning materials about technology and strategy for #Startup and/or #Scaleup.',
#  'url': None,
#  'entities': {'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 467,
#  'friends_count': 471,
#  'listed_count': 3,
#  'created_at': 'Mon Dec 25 06:49:05 +0000 2017',
#  'favourites_count': 1848,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': False,
#  'verified': False,
#  'statuses_count': 1635,
#  'lang': None,
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': 'F5F8FA',
#  'profile_background_image_url': None,
#  'profile_background_image_url_https': None,
#  'profile_background_tile': False,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1161279306011688962/EzVWLANP_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1161279306011688962/EzVWLANP_normal.jpg',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/945184607728734209/1565705713',
#  'profile_link_color': '1DA1F2',
#  'profile_sidebar_border_color': 'C0DEED',
#  'profile_sidebar_fill_color': 'DDEEF6',
#  'profile_text_color': '333333',
#  'profile_use_background_image': True,
#  'has_extended_profile': False,
#  'default_profile': True,
#  'default_profile_image': False,
#  'following': False,
#  'follow_request_sent': False,
#  'notifications': False,
#  'translator_type': 'none'}

# %%
user = tweets[0]['user']
print('screen_name=%s, name=%s, location=%s' % (user['screen_name'], user['name'], user['location']))
# Out:
# screen_name=StartupNScaleup, name=Startup Or Scaleup, location=Global

# %%
# Who follows this person?
# https://dev.twitter.com/docs/api/1.1/get/followers/list
screen_name = user['screen_name']
response  = twitter.request('followers/list', {'screen_name': screen_name, 'count':200})
followers = [follower for follower in response]
        
print('found %d followers for %s' % (len(followers), screen_name))
# See more about paging here: https://dev.twitter.com/docs/working-with-timelines
# Out:
# found 200 followers for StartupNScaleup

# %% [markdown]
# # Get Twitter account timeline for the screen-name

# %%
screen_name = 'FOXSports'
timeline = [tweet for tweet in twitter.request('statuses/user_timeline',
                                                {'screen_name': screen_name,
                                                 'count': 200})]
print('got %d tweets for user %s' % (len(timeline), screen_name))
# Out:
# got 200 tweets for user TwitterSports

# %%
# Print time got created.

# timeline[3]['entities']['media'][0]['media_url_https']

# %%
# Print the text.
print('\n\n\n'.join(t['text'] for t in timeline))

# %%
# Count words
from collections import Counter  # This is just a fancy dict mapping from object->int, starting at 0.
counts = Counter()
for tweet in timeline:
    counts.update(tweet['text'].lower().split())
print('found %d unique terms in %d tweets' % (len(counts), len(timeline)))
counts.most_common(10)

# %%
import re
for tweet in timeline:
    deal = tweet['text']
    print(deal + '\n')

# %% [markdown]
# # Find  the latest tweets in sports and display live from using twitter api

# %%
import re
import pymysql

cnx = pymysql.connect(user='root', password='rakshu',
                              host='127.0.0.1',
                              database='sportshub')
cursor = cnx.cursor()

query = ("SELECT subGenre FROM Eventdetails group by subGenre;")
cursor.execute(query)


dealMatchGauranteed=[]
for product in cursor:
    for tweet in timeline:
        deal = (tweet['text'])
#         if 'media' in (tweet['entities']):
#            deal = deal + " image: " + tweet['entities']['media'][0]['media_url_https']
        if (len(re.findall('\s'+product[0]+'\s',deal)) >= 1):
            dealMatchGauranteed = dealMatchGauranteed + [deal]

# %%
# Sanity Test that  we got some deals
dealMatchGauranteed[:10]
# Out:
# ['Waiting for news from the NFL trade deadline like https://t.co/5KwECCwYR5',
#  "@DaveeC_ There's five NBA games on Sunday 😎",
#  "Come for this year's NBA rookie class, stay for the memes \n\n#NBATwitter https://t.co/oa6zmuSV8M",
#  "RT @espn: It's Saturday. College football is on. \n\n@TreavorScales, @elleduncanESPN and @garystriewski are here for all of it on The College…",
#  'RT @espn: Week 11 in CFB = WILD 🤯\n\n\n@TreavorScales, @garystriewski and @Bcarp3 break it all down on The College Football Show! https://t.co…',
#  'There are 268 D1 College Basketball games today. \n\nWelcome back.',
#  'RT @espn: .@TreavorScales, @garystriewski and @Bcarp3 recap the biggest moments of the day on The College Football Show! \n https://t.co/xij…',
#  'RT @espn: Another WILD Saturday. The only place to get all the details is the College Football Show with our hosts @TreavorScales, @garystr…']

# %% [markdown]
# # Create and write the latest news into DealMatches.txt file that will be used by web-app of SportsHub in LatestNews Section

# %%
dealMatchFile = open(r'C:\apache-tomcat-7.0.34\webapps\EWA_Project\DealMatches.txt', 'w')
for deal in dealMatchGauranteed:
    deal = re.sub(r"[^A-Za-z0-9\/:;&-. <>=\"_'$@?!#*]+","",deal)
    dealMatchFile.write("%s\n" % deal)

dealMatchFile.close()

# %%
timeline
# Out:
# [{'created_at': 'Sun Nov 24 00:03:51 +0000 2019',
#   'id': 1198391744842403845,
#   'id_str': '1198391744842403845',
#   'text': 'RT @espn: Another week and the #CFBPlayoff picture continues to get clearer and clearer.\n\n@TreavorScales, @garystriewski, and @HDouglas83 b…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'CFBPlayoff', 'indices': [31, 42]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'espn',
#      'name': 'ESPN',
#      'id': 2557521,
#      'id_str': '2557521',
#      'indices': [3, 8]},
#     {'screen_name': 'TreavorScales',
#      'name': 'Treavor Scales',
#      'id': 453144112,
#      'id_str': '453144112',
#      'indices': [90, 104]},
#     {'screen_name': 'garystriewski',
#      'name': 'Gary Striewski',
#      'id': 113236871,
#      'id_str': '113236871',
#      'indices': [106, 120]},
#     {'screen_name': 'HDouglas83',
#      'name': 'Harry Douglas',
#      'id': 316795090,
#      'id_str': '316795090',
#      'indices': [126, 137]}],
#    'urls': []},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 300392950,
#    'id_str': '300392950',
#    'name': 'Twitter Sports',
#    'screen_name': 'TwitterSports',
#    'location': '',
#    'description': "Kickin' it",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 15254106,
#    'friends_count': 1992,
#    'listed_count': 8797,
#    'created_at': 'Tue May 17 17:54:29 +0000 2011',
#    'favourites_count': 11845,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 17319,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/300392950/1559852874',
#    'profile_link_color': '4A913C',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'can_media_tag': True,
#    'followed_by': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sun Nov 24 00:03:12 +0000 2019',
#    'id': 1198391580404649984,
#    'id_str': '1198391580404649984',
#    'text': 'Another week and the #CFBPlayoff picture continues to get clearer and clearer.\n\n@TreavorScales, @garystriewski, and… https://t.co/rqHY1I6GGK',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'CFBPlayoff', 'indices': [21, 32]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'TreavorScales',
#       'name': 'Treavor Scales',
#       'id': 453144112,
#       'id_str': '453144112',
#       'indices': [80, 94]},
#      {'screen_name': 'garystriewski',
#       'name': 'Gary Striewski',
#       'id': 113236871,
#       'id_str': '113236871',
#       'indices': [96, 110]}],
#     'urls': [{'url': 'https://t.co/rqHY1I6GGK',
#       'expanded_url': 'https://twitter.com/i/web/status/1198391580404649984',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="https://studio.twitter.com" rel="nofollow">Twitter Media Studio</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2557521,
#     'id_str': '2557521',
#     'name': 'ESPN',
#     'screen_name': 'espn',
#     'location': '',
#     'description': 'Download the ESPN App ⬇️',
#     'url': 'https://t.co/RqqkIx8GI7',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/RqqkIx8GI7',
#         'expanded_url': 'http://es.pn/app',
#         'display_url': 'es.pn/app',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 34524502,
#     'friends_count': 308,
#     'listed_count': 60205,
#     'created_at': 'Tue Mar 27 20:46:16 +0000 2007',
#     'favourites_count': 340,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 106887,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': True,
#     'profile_background_color': 'C8C8C8',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1170690523201527808/FriNRiir_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1170690523201527808/FriNRiir_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2557521/1516042897',
#     'profile_link_color': 'CC0000',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'EFEFEF',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'can_media_tag': True,
#     'followed_by': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'regular'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 31,
#    'favorite_count': 256,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 31,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Fri Nov 22 18:26:09 +0000 2019',
#   'id': 1197944369808134145,
#   'id_str': '1197944369808134145',
#   'text': '@WWEonFOX It already happened. WrestleMania 17.',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'WWEonFOX',
#      'name': 'WWE on FOX',
#      'id': 1115420364220145664,
#      'id_str': '1115420364220145664',
#      'indices': [0, 9]}],
#    'urls': []},
#   'source': '<a href="https://www.sprinklr.com" rel="nofollow">Sprinklr</a>',
#   'in_reply_to_status_id': 1197940028900380672,
#   'in_reply_to_status_id_str': '1197940028900380672',
#   'in_reply_to_user_id': 1115420364220145664,
#   'in_reply_to_user_id_str': '1115420364220145664',
#   'in_reply_to_screen_name': 'WWEonFOX',
#   'user': {'id': 300392950,
#    'id_str': '300392950',
#    'name': 'Twitter Sports',
#    'screen_name': 'TwitterSports',
#    'location': '',
#    'description': "Kickin' it",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 15254106,
#    'friends_count': 1992,
#    'listed_count': 8797,
#    'created_at': 'Tue May 17 17:54:29 +0000 2011',
#    'favourites_count': 11845,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 17319,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/300392950/1559852874',
#    'profile_link_color': '4A913C',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'can_media_tag': True,
#    'followed_by': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 15,
#   'favorite_count': 188,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Nov 21 23:08:36 +0000 2019',
#   'id': 1197653065446375424,
#   'id_str': '1197653065446375424',
#   'text': '@CuffsTheLegend Kareem is the only answer',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'CuffsTheLegend',
#      'name': '73-9 and they LIED 🏁',
#      'id': 24007253,
#      'id_str': '24007253',
#      'indices': [0, 15]}],
#    'urls': []},
#   'source': '<a href="https://www.sprinklr.com" rel="nofollow">Sprinklr</a>',
#   'in_reply_to_status_id': 1197632780299055106,
#   'in_reply_to_status_id_str': '1197632780299055106',
#   'in_reply_to_user_id': 24007253,
#   'in_reply_to_user_id_str': '24007253',
#   'in_reply_to_screen_name': 'CuffsTheLegend',
#   'user': {'id': 300392950,
#    'id_str': '300392950',
#    'name': 'Twitter Sports',
#    'screen_name': 'TwitterSports',
#    'location': '',
#    'description': "Kickin' it",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 15254106,
#    'friends_count': 1992,
#    'listed_count': 8797,
#    'created_at': 'Tue May 17 17:54:29 +0000 2011',
#    'favourites_count': 11845,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 17319,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/300392950/1559852874',
#    'profile_link_color': '4A913C',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'can_media_tag': True,
#    'followed_by': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 3,
#   'favorite_count': 20,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Nov 21 21:51:39 +0000 2019',
#   'id': 1197633697714802689,
#   'id_str': '1197633697714802689',
#   'text': 'The butt fumble was on Thanksgiving',
#   'truncated': False,
#   'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 300392950,
#    'id_str': '300392950',
#    'name': 'Twitter Sports',
#    'screen_name': 'TwitterSports',
#    'location': '',
#    'description': "Kickin' it",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 15254106,
#    'friends_count': 1992,
#    'listed_count': 8797,
#    'created_at': 'Tue May 17 17:54:29 +0000 2011',
#    'favourites_count': 11845,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 17319,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/300392950/1559852874',
#    'profile_link_color': '4A913C',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'can_media_tag': True,
#    'followed_by': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 21,
#   'favorite_count': 108,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Nov 21 19:26:00 +0000 2019',
#   'id': 1197597045009334272,
#   'id_str': '1197597045009334272',
#   'text': '@antoinette6ix We agree',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'antoinette6ix',
#      'name': 'Antoinette',
#      'id': 28003281,
#      'id_str': '28003281',
#      'indices': [0, 14]}],
#    'urls': []},
#   'source': '<a href="https://www.sprinklr.com" rel="nofollow">Sprinklr</a>',
#   'in_reply_to_status_id': 1197589722723426304,
#   'in_reply_to_status_id_str': '1197589722723426304',
#   'in_reply_to_user_id': 28003281,
#   'in_reply_to_user_id_str': '28003281',
#   'in_reply_to_screen_name': 'antoinette6ix',
#   'user': {'id': 300392950,
#    'id_str': '300392950',
#    'name': 'Twitter Sports',
#    'screen_name': 'TwitterSports',
#    'location': '',
#    'description': "Kickin' it",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 15254106,
#    'friends_count': 1992,
#    'listed_count': 8797,
#    'created_at': 'Tue May 17 17:54:29 +0000 2011',
#    'favourites_count': 11845,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 17319,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/300392950/1559852874',
#    'profile_link_color': '4A913C',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'can_media_tag': True,
#    'followed_by': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 2,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Nov 21 17:52:48 +0000 2019',
#   'id': 1197573588519395328,
#   'id_str': '1197573588519395328',
#   'text': '@ringernba We think about this every day.',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'ringernba',
#      'name': '#NBADesktop',
#      'id': 768110798770212867,
#      'id_str': '768110798770212867',
#      'indices': [0, 10]}],
#    'urls': []},
#   'source': '<a href="https://www.sprinklr.com" rel="nofollow">Sprinklr</a>',
#   'in_reply_to_status_id': 1197561290106884096,
#   'in_reply_to_status_id_str': '1197561290106884096',
#   'in_reply_to_user_id': 768110798770212867,
#   'in_reply_to_user_id_str': '768110798770212867',
#   'in_reply_to_screen_name': 'ringernba',
#   'user': {'id': 300392950,
#    'id_str': '300392950',
#    'name': 'Twitter Sports',
#    'screen_name': 'TwitterSports',
#    'location': '',
#    'description': "Kickin' it",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 15254106,
#    'friends_count': 1992,
#    'listed_count': 8797,
#    'created_at': 'Tue May 17 17:54:29 +0000 2011',
#    'favourites_count': 11845,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 17319,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/300392950/1559852874',
#    'profile_link_color': '4A913C',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'can_media_tag': True,
#    'followed_by': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 3,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Nov 21 17:52:17 +0000 2019',
#   'id': 1197573462488965121,
#   'id_str': '1197573462488965121',
#   'text': "@Seahawks Might sound crazy but it ain't no lie",
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'Seahawks',
#      'name': 'Seattle Seahawks',
#      'id': 23642374,
#      'id_str': '23642374',
#      'indices': [0, 9]}],
#    'urls': []},
#   'source': '<a href="https://www.sprinklr.com" rel="nofollow">Sprinklr</a>',
#   'in_reply_to_status_id': 1197566591249965056,
#   'in_reply_to_status_id_str': '1197566591249965056',
#   'in_reply_to_user_id': 23642374,
#   'in_reply_to_user_id_str': '23642374',
#   'in_reply_to_screen_name': 'Seahawks',
#   'user': {'id': 300392950,
#    'id_str': '300392950',
#    'name': 'Twitter Sports',
#    'screen_name': 'TwitterSports',
#    'location': '',
#    'description': "Kickin' it",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 15254106,
#    'friends_count': 1992,
#    'listed_count': 8797,
#    'created_at': 'Tue May 17 17:54:29 +0000 2011',
#    'favourites_count': 11845,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 17319,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/300392950/1559852874',
#    'profile_link_color': '4A913C',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'can_media_tag': True,
#    'followed_by': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 1,
#   'favorite_count': 45,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Nov 21 17:51:10 +0000 2019',
#   'id': 1197573178803011586,
#   'id_str': '1197573178803011586',
#   'text': '@Ravens Does this mean The Annexation of Puerto Rico has been added to the playbook?',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'Ravens',
#      'name': 'Baltimore Ravens',
#      'id': 22146282,
#      'id_str': '22146282',
#      'indices': [0, 7]}],
#    'urls': []},
#   'source': '<a href="https://www.sprinklr.com" rel="nofollow">Sprinklr</a>',
#   'in_reply_to_status_id': 1197571983459926016,
#   'in_reply_to_status_id_str': '1197571983459926016',
#   'in_reply_to_user_id': 22146282,
#   'in_reply_to_user_id_str': '22146282',
#   'in_reply_to_screen_name': 'Ravens',
#   'user': {'id': 300392950,
#    'id_str': '300392950',
#    'name': 'Twitter Sports',
#    'screen_name': 'TwitterSports',
#    'location': '',
#    'description': "Kickin' it",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 15254106,
#    'friends_count': 1992,
#    'listed_count': 8797,
#    'created_at': 'Tue May 17 17:54:29 +0000 2011',
#    'favourites_count': 11845,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 17319,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/300392950/1559852874',
#    'profile_link_color': '4A913C',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'can_media_tag': True,
#    'followed_by': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 5,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Nov 20 17:54:10 +0000 2019',
#   'id': 1197211546960699392,
#   'id_str': '1197211546960699392',
#   'text': "@GrantGoldberg We'd wear it",
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'GrantGoldberg',
#      'name': 'Grant Goldberg',
#      'id': 230988887,
#      'id_str': '230988887',
#      'indices': [0, 14]}],
#    'urls': []},
#   'source': '<a href="https://www.sprinklr.com" rel="nofollow">Sprinklr</a>',
#   'in_reply_to_status_id': 1196941988030865408,
#   'in_reply_to_status_id_str': '1196941988030865408',
#   'in_reply_to_user_id': 230988887,
#   'in_reply_to_user_id_str': '230988887',
#   'in_reply_to_screen_name': 'GrantGoldberg',
#   'user': {'id': 300392950,
#    'id_str': '300392950',
#    'name': 'Twitter Sports',
#    'screen_name': 'TwitterSports',
#    'location': '',
#    'description': "Kickin' it",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 15254106,
#    'friends_count': 1992,
#    'listed_count': 8797,
#    'created_at': 'Tue May 17 17:54:29 +0000 2011',
#    'favourites_count': 11845,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 17319,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/300392950/1559852874',
#    'profile_link_color': '4A913C',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'can_media_tag': True,
#    'followed_by': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 1,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Tue Nov 19 20:34:03 +0000 2019',
#   'id': 1196889395955216384,
#   'id_str': '1196889395955216384',
#   'text': '@FitzGSN_ If we had it on June 17, 1994 that would be enough',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'FitzGSN_',
#      'name': 'Fitz',
#      'id': 184571109,
#      'id_str': '184571109',
#      'indices': [0, 9]}],
#    'urls': []},
#   'source': '<a href="https://www.sprinklr.com" rel="nofollow">Sprinklr</a>',
#   'in_reply_to_status_id': 1196864557202989056,
#   'in_reply_to_status_id_str': '1196864557202989056',
#   'in_reply_to_user_id': 184571109,
#   'in_reply_to_user_id_str': '184571109',
#   'in_reply_to_screen_name': 'FitzGSN_',
#   'user': {'id': 300392950,
#    'id_str': '300392950',
#    'name': 'Twitter Sports',
#    'screen_name': 'TwitterSports',
#    'location': '',
#    'description': "Kickin' it",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 15254106,
#    'friends_count': 1992,
#    'listed_count': 8797,
#    'created_at': 'Tue May 17 17:54:29 +0000 2011',
#    'favourites_count': 11845,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 17319,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/300392950/1559852874',
#    'profile_link_color': '4A913C',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'can_media_tag': True,
#    'followed_by': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 4,
#   'favorite_count': 36,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Tue Nov 19 20:33:00 +0000 2019',
#   'id': 1196889129478492160,
#   'id_str': '1196889129478492160',
#   'text': "@tim_cato There's a lot to unpack here but we'd like to start with the gradient",
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'tim_cato',
#      'name': 'Tim Cato',
#      'id': 560447335,
#      'id_str': '560447335',
#      'indices': [0, 9]}],
#    'urls': []},
#   'source': '<a href="https://www.sprinklr.com" rel="nofollow">Sprinklr</a>',
#   'in_reply_to_status_id': 1196874038691405824,
#   'in_reply_to_status_id_str': '1196874038691405824',
#   'in_reply_to_user_id': 560447335,
#   'in_reply_to_user_id_str': '560447335',
#   'in_reply_to_screen_name': 'tim_cato',
#   'user': {'id': 300392950,
#    'id_str': '300392950',
#    'name': 'Twitter Sports',
#    'screen_name': 'TwitterSports',
#    'location': '',
#    'description': "Kickin' it",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 15254106,
#    'friends_count': 1992,
#    'listed_count': 8797,
#    'created_at': 'Tue May 17 17:54:29 +0000 2011',
#    'favourites_count': 11845,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 17319,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/300392950/1559852874',
#    'profile_link_color': '4A913C',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'can_media_tag': True,
#    'followed_by': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 1,
#   'favorite_count': 13,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Tue Nov 19 19:15:57 +0000 2019',
#   'id': 1196869740381257728,
#   'id_str': '1196869740381257728',
#   'text': 'CARMEL00',
#   'truncated': False,
#   'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#   'source': '<a href="https://www.sprinklr.com" rel="nofollow">Sprinklr</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 300392950,
#    'id_str': '300392950',
#    'name': 'Twitter Sports',
#    'screen_name': 'TwitterSports',
#    'location': '',
#    'description': "Kickin' it",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 15254106,
#    'friends_count': 1992,
#    'listed_count': 8797,
#    'created_at': 'Tue May 17 17:54:29 +0000 2011',
#    'favourites_count': 11845,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 17319,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/300392950/1559852874',
#    'profile_link_color': '4A913C',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'can_media_tag': True,
#    'followed_by': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 26,
#   'favorite_count': 106,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Tue Nov 19 18:53:47 +0000 2019',
#   'id': 1196864163148120066,
#   'id_str': '1196864163148120066',
#   'text': '@QuadCitiesPat Temecula is the 🐐',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'QuadCitiesPat',
#      'name': 'Patrick',
#      'id': 954034288223309824,
#      'id_str': '954034288223309824',
#      'indices': [0, 14]}],
#    'urls': []},
#   'source': '<a href="https://www.sprinklr.com" rel="nofollow">Sprinklr</a>',
#   'in_reply_to_status_id': 1196576562956656640,
#   'in_reply_to_status_id_str': '1196576562956656640',
#   'in_reply_to_user_id': 954034288223309824,
#   'in_reply_to_user_id_str': '954034288223309824',
#   'in_reply_to_screen_name': 'QuadCitiesPat',
#   'user': {'id': 300392950,
#    'id_str': '300392950',
#    'name': 'Twitter Sports',
#    'screen_name': 'TwitterSports',
#    'location': '',
#    'description': "Kickin' it",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 15254106,
#    'friends_count': 1992,
#    'listed_count': 8797,
#    'created_at': 'Tue May 17 17:54:29 +0000 2011',
#    'favourites_count': 11845,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 17319,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/300392950/1559852874',
#    'profile_link_color': '4A913C',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'can_media_tag': True,
#    'followed_by': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Tue Nov 19 18:30:31 +0000 2019',
#   'id': 1196858305555189762,
#   'id_str': '1196858305555189762',
#   'text': "@SLAMftw Hey look it's a picture of us and @TwitterGaming",
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'SLAMftw',
#      'name': 'SLAM Gaming',
#      'id': 1123608706564935682,
#      'id_str': '1123608706564935682',
#      'indices': [0, 8]},
#     {'screen_name': 'TwitterGaming',
#      'name': 'Twitter Gaming',
#      'id': 3873936134,
#      'id_str': '3873936134',
#      'indices': [43, 57]}],
#    'urls': []},
#   'source': '<a href="https://www.sprinklr.com" rel="nofollow">Sprinklr</a>',
#   'in_reply_to_status_id': 1196850905662083080,
#   'in_reply_to_status_id_str': '1196850905662083080',
#   'in_reply_to_user_id': 1123608706564935682,
#   'in_reply_to_user_id_str': '1123608706564935682',
#   'in_reply_to_screen_name': 'SLAMftw',
#   'user': {'id': 300392950,
#    'id_str': '300392950',
#    'name': 'Twitter Sports',
#    'screen_name': 'TwitterSports',
#    'location': '',
#    'description': "Kickin' it",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 15254106,
#    'friends_count': 1992,
#    'listed_count': 8797,
#    'created_at': 'Tue May 17 17:54:29 +0000 2011',
#    'favourites_count': 11845,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 17319,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/300392950/1559852874',
#    'profile_link_color': '4A913C',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'can_media_tag': True,
#    'followed_by': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 2,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Mon Nov 18 21:59:42 +0000 2019',
#   'id': 1196548560680079360,
#   'id_str': '1196548560680079360',
#   'text': '@therhysdeiter 😔',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'therhysdeiter',
#      'name': 'Rhys Deiter',
#      'id': 765919005848834048,
#      'id_str': '765919005848834048',
#      'indices': [0, 14]}],
#    'urls': []},
#   'source': '<a href="https://www.sprinklr.com" rel="nofollow">Sprinklr</a>',
#   'in_reply_to_status_id': 1196279368294838272,
#   'in_reply_to_status_id_str': '1196279368294838272',
#   'in_reply_to_user_id': 765919005848834048,
#   'in_reply_to_user_id_str': '765919005848834048',
#   'in_reply_to_screen_name': 'therhysdeiter',
#   'user': {'id': 300392950,
#    'id_str': '300392950',
#    'name': 'Twitter Sports',
#    'screen_name': 'TwitterSports',
#    'location': '',
#    'description': "Kickin' it",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 15254106,
#    'friends_count': 1992,
#    'listed_count': 8797,
#    'created_at': 'Tue May 17 17:54:29 +0000 2011',
#    'favourites_count': 11845,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 17319,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/300392950/1559852874',
#    'profile_link_color': '4A913C',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'can_media_tag': True,
#    'followed_by': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 3,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'und'},
#  {'created_at': 'Mon Nov 18 21:58:38 +0000 2019',
#   'id': 1196548291888062464,
#   'id_str': '1196548291888062464',
#   'text': '@TheTraeYoung @kobebryant #JustAsExcitedToMeetGigi is a mood and we can relate',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'JustAsExcitedToMeetGigi',
#      'indices': [26, 50]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'TheTraeYoung',
#      'name': 'Trae Young',
#      'id': 2842841126,
#      'id_str': '2842841126',
#      'indices': [0, 13]},
#     {'screen_name': 'kobebryant',
#      'name': 'Kobe Bryant',
#      'id': 1059194370,
#      'id_str': '1059194370',
#      'indices': [14, 25]}],
#    'urls': []},
#   'source': '<a href="https://www.sprinklr.com" rel="nofollow">Sprinklr</a>',
#   'in_reply_to_status_id': 1196315653029806080,
#   'in_reply_to_status_id_str': '1196315653029806080',
#   'in_reply_to_user_id': 2842841126,
#   'in_reply_to_user_id_str': '2842841126',
#   'in_reply_to_screen_name': 'TheTraeYoung',
#   'user': {'id': 300392950,
#    'id_str': '300392950',
#    'name': 'Twitter Sports',
#    'screen_name': 'TwitterSports',
#    'location': '',
#    'description': "Kickin' it",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 15254106,
#    'friends_count': 1992,
#    'listed_count': 8797,
#    'created_at': 'Tue May 17 17:54:29 +0000 2011',
#    'favourites_count': 11845,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 17319,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/300392950/1559852874',
#    'profile_link_color': '4A913C',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'can_media_tag': True,
#    'followed_by': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 3,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Mon Nov 18 21:55:56 +0000 2019',
#   'id': 1196547613111279616,
#   'id_str': '1196547613111279616',
#   'text': '@SportsCenter is it really "new" tho',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'SportsCenter',
#      'name': 'SportsCenter',
#      'id': 26257166,
#      'id_str': '26257166',
#      'indices': [0, 13]}],
#    'urls': []},
#   'source': '<a href="https://www.sprinklr.com" rel="nofollow">Sprinklr</a>',
#   'in_reply_to_status_id': 1196479862644649987,
#   'in_reply_to_status_id_str': '1196479862644649987',
#   'in_reply_to_user_id': 26257166,
#   'in_reply_to_user_id_str': '26257166',
#   'in_reply_to_screen_name': 'SportsCenter',
#   'user': {'id': 300392950,
#    'id_str': '300392950',
#    'name': 'Twitter Sports',
#    'screen_name': 'TwitterSports',
#    'location': '',
#    'description': "Kickin' it",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 15254106,
#    'friends_count': 1992,
#    'listed_count': 8797,
#    'created_at': 'Tue May 17 17:54:29 +0000 2011',
#    'favourites_count': 11845,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 17319,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/300392950/1559852874',
#    'profile_link_color': '4A913C',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'can_media_tag': True,
#    'followed_by': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
# ...
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/300392950/1559852874',
#    'profile_link_color': '4A913C',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'can_media_tag': True,
#    'followed_by': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 18,
#   'favorite_count': 362,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'und'},
#  {'created_at': 'Tue Oct 15 22:27:12 +0000 2019',
#   'id': 1184234295080042496,
#   'id_str': '1184234295080042496',
#   'text': '@MLS https://t.co/VkBajOnIBH',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'MLS',
#      'name': 'Major League Soccer',
#      'id': 107146095,
#      'id_str': '107146095',
#      'indices': [0, 4]}],
#    'urls': [],
#    'media': [{'id': 1184234289946185732,
#      'id_str': '1184234289946185732',
#      'indices': [5, 28],
#      'media_url': 'http://pbs.twimg.com/tweet_video_thumb/EG8-z_cUUAQZapy.jpg',
#      'media_url_https': 'https://pbs.twimg.com/tweet_video_thumb/EG8-z_cUUAQZapy.jpg',
#      'url': 'https://t.co/VkBajOnIBH',
#      'display_url': 'pic.twitter.com/VkBajOnIBH',
#      'expanded_url': 'https://twitter.com/TwitterSports/status/1184234295080042496/photo/1',
#      'type': 'photo',
#      'sizes': {'medium': {'w': 480, 'h': 270, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 480, 'h': 270, 'resize': 'fit'},
#       'large': {'w': 480, 'h': 270, 'resize': 'fit'}},
#      'features': {}}]},
#   'extended_entities': {'media': [{'id': 1184234289946185732,
#      'id_str': '1184234289946185732',
#      'indices': [5, 28],
#      'media_url': 'http://pbs.twimg.com/tweet_video_thumb/EG8-z_cUUAQZapy.jpg',
#      'media_url_https': 'https://pbs.twimg.com/tweet_video_thumb/EG8-z_cUUAQZapy.jpg',
#      'url': 'https://t.co/VkBajOnIBH',
#      'display_url': 'pic.twitter.com/VkBajOnIBH',
#      'expanded_url': 'https://twitter.com/TwitterSports/status/1184234295080042496/photo/1',
#      'type': 'animated_gif',
#      'sizes': {'medium': {'w': 480, 'h': 270, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 480, 'h': 270, 'resize': 'fit'},
#       'large': {'w': 480, 'h': 270, 'resize': 'fit'}},
#      'video_info': {'aspect_ratio': [16, 9],
#       'variants': [{'bitrate': 0,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/tweet_video/EG8-z_cUUAQZapy.mp4'}]},
#      'features': {}}]},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': 1184196420666122241,
#   'in_reply_to_status_id_str': '1184196420666122241',
#   'in_reply_to_user_id': 107146095,
#   'in_reply_to_user_id_str': '107146095',
#   'in_reply_to_screen_name': 'MLS',
#   'user': {'id': 300392950,
#    'id_str': '300392950',
#    'name': 'Twitter Sports',
#    'screen_name': 'TwitterSports',
#    'location': '',
#    'description': "Kickin' it",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 15254106,
#    'friends_count': 1992,
#    'listed_count': 8797,
#    'created_at': 'Tue May 17 17:54:29 +0000 2011',
#    'favourites_count': 11845,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 17319,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/300392950/1559852874',
#    'profile_link_color': '4A913C',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'can_media_tag': True,
#    'followed_by': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 1,
#   'favorite_count': 5,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'und'},
#  {'created_at': 'Tue Oct 15 21:26:20 +0000 2019',
#   'id': 1184218978765463553,
#   'id_str': '1184218978765463553',
#   'text': '@dylanward2023 When will see them together on the court tho?\n🤔',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'dylanward2023',
#      'name': 'dylan ward',
#      'id': 1067839735723421696,
#      'id_str': '1067839735723421696',
#      'indices': [0, 14]}],
#    'urls': []},
#   'source': '<a href="https://www.sprinklr.com" rel="nofollow">Sprinklr</a>',
#   'in_reply_to_status_id': 1184176415484198914,
#   'in_reply_to_status_id_str': '1184176415484198914',
#   'in_reply_to_user_id': 1067839735723421696,
#   'in_reply_to_user_id_str': '1067839735723421696',
#   'in_reply_to_screen_name': 'dylanward2023',
#   'user': {'id': 300392950,
#    'id_str': '300392950',
#    'name': 'Twitter Sports',
#    'screen_name': 'TwitterSports',
#    'location': '',
#    'description': "Kickin' it",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 15254106,
#    'friends_count': 1992,
#    'listed_count': 8797,
#    'created_at': 'Tue May 17 17:54:29 +0000 2011',
#    'favourites_count': 11845,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 17319,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/300392950/1559852874',
#    'profile_link_color': '4A913C',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'can_media_tag': True,
#    'followed_by': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Tue Oct 15 21:25:38 +0000 2019',
#   'id': 1184218800285257729,
#   'id_str': '1184218800285257729',
#   'text': '@405Doop The Rockets are ready for blast off',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': '405Doop',
#      'name': 'R.J. Deupree',
#      'id': 122266972,
#      'id_str': '122266972',
#      'indices': [0, 8]}],
#    'urls': []},
#   'source': '<a href="https://www.sprinklr.com" rel="nofollow">Sprinklr</a>',
#   'in_reply_to_status_id': 1184178555913150467,
#   'in_reply_to_status_id_str': '1184178555913150467',
#   'in_reply_to_user_id': 122266972,
#   'in_reply_to_user_id_str': '122266972',
#   'in_reply_to_screen_name': '405Doop',
#   'user': {'id': 300392950,
#    'id_str': '300392950',
#    'name': 'Twitter Sports',
#    'screen_name': 'TwitterSports',
#    'location': '',
#    'description': "Kickin' it",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 15254106,
#    'friends_count': 1992,
#    'listed_count': 8797,
#    'created_at': 'Tue May 17 17:54:29 +0000 2011',
#    'favourites_count': 11845,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 17319,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/300392950/1559852874',
#    'profile_link_color': '4A913C',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'can_media_tag': True,
#    'followed_by': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 1,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Tue Oct 15 21:25:38 +0000 2019',
#   'id': 1184218799811248128,
#   'id_str': '1184218799811248128',
#   'text': '@ofria117 Oh, we ready.',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'ofria117',
#      'name': 'Ofria',
#      'id': 3135786584,
#      'id_str': '3135786584',
#      'indices': [0, 9]}],
#    'urls': []},
#   'source': '<a href="https://www.sprinklr.com" rel="nofollow">Sprinklr</a>',
#   'in_reply_to_status_id': 1184176814882721798,
#   'in_reply_to_status_id_str': '1184176814882721798',
#   'in_reply_to_user_id': 3135786584,
#   'in_reply_to_user_id_str': '3135786584',
#   'in_reply_to_screen_name': 'ofria117',
#   'user': {'id': 300392950,
#    'id_str': '300392950',
#    'name': 'Twitter Sports',
#    'screen_name': 'TwitterSports',
#    'location': '',
#    'description': "Kickin' it",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 15254106,
#    'friends_count': 1992,
#    'listed_count': 8797,
#    'created_at': 'Tue May 17 17:54:29 +0000 2011',
#    'favourites_count': 11845,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 17319,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/300392950/1559852874',
#    'profile_link_color': '4A913C',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'can_media_tag': True,
#    'followed_by': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Tue Oct 15 21:24:07 +0000 2019',
#   'id': 1184218420151226370,
#   'id_str': '1184218420151226370',
#   'text': '@juliephayer The NBA, cats, and Julie are the new Big 3',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'juliephayer',
#      'name': 'julie',
#      'id': 47548476,
#      'id_str': '47548476',
#      'indices': [0, 12]}],
#    'urls': []},
#   'source': '<a href="https://www.sprinklr.com" rel="nofollow">Sprinklr</a>',
#   'in_reply_to_status_id': 1184176997313863680,
#   'in_reply_to_status_id_str': '1184176997313863680',
#   'in_reply_to_user_id': 47548476,
#   'in_reply_to_user_id_str': '47548476',
#   'in_reply_to_screen_name': 'juliephayer',
#   'user': {'id': 300392950,
#    'id_str': '300392950',
#    'name': 'Twitter Sports',
#    'screen_name': 'TwitterSports',
#    'location': '',
#    'description': "Kickin' it",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 15254106,
#    'friends_count': 1992,
#    'listed_count': 8797,
#    'created_at': 'Tue May 17 17:54:29 +0000 2011',
#    'favourites_count': 11845,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 17319,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1016780795556528128/rwOTWVjg_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/300392950/1559852874',
#    'profile_link_color': '4A913C',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'can_media_tag': True,
#    'followed_by': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 1,
#   'favorite_count': 10,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'}]
